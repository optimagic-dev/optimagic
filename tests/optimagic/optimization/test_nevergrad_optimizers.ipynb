# %%
import numpy as np

import optimagic as om
from optimagic.optimizers.nevergrad_optimizers import NevergradOnePlusOne

res = om.minimize(
    fun=lambda x: (x - 0.7) @ x,
    params=np.arange(5),
    algorithm=NevergradOnePlusOne,
    bounds=om.Bounds(lower=-np.ones(5) - 2, upper=np.ones(5)),
)

om.criterion_plot(res, monotone=True)

# %%
import numpy as np

import optimagic as om
from optimagic.optimizers.pygmo_optimizers import PygmoGaco

res = om.minimize(
    fun=lambda x: x @ x,
    params=np.arange(5),
    algorithm=PygmoGaco,
    bounds=om.Bounds(lower=-np.ones(5) - 2, upper=np.ones(5)),
)

om.criterion_plot(res, monotone=True)
